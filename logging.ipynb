# %%
import logging

# %%
logger = logging.getLogger(__name__)
logger
# Out:
# <Logger __main__ (INFO)>

# %%
logging.basicConfig(filename="myapp.log", level=logging.INFO)

# %%
logger.info("Started")

# %%
int("5.3")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 int("5.3")
#
# ValueError: invalid literal for int() with base 10: '5.3'

# %%
import sys

sys.orig_argv
# Out:
# ['C:\\Users\\Pajas\\AppData\\Roaming\\uv\\python\\cpython-3.12-windows-x86_64-none\\python.exe',
#  '-m',
#  'ipykernel_launcher',
#  '--f=c:\\Users\\Pajas\\AppData\\Roaming\\jupyter\\runtime\\kernel-v33c577d86055f2e440995b000ba69133870a41341.json']

# %%
logger.info("Finished")

# %%
"The sum of {a} and {b} is {0} {0} and not {1}".format(3, 4, a=1, b=2)
# Out:
# 'The sum of 1 and 2 is 3 3 and not 4'
